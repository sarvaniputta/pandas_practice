# %% [markdown]
# ## Baseball-specific analysis

# %% [markdown]
# D) List the 20 most dangerous pitchers derived from their career total statistics. Specifically, those with the highest career rates of hitting batters. (Join People & Pitching tables. Use the formula total “Batters Hit By Pitch” / total “Outs Pitched”)

# %%
import pandas as pd
import numpy as np
import doctest

# %% [markdown]
# Read the data files for pitches and player names

# %%
pitching = pd.read_csv('baseballdatabank-2019.2/baseballdatabank-2019.2/core/Pitching.csv')

# %%
people = pd.read_csv('baseballdatabank-2019.2/baseballdatabank-2019.2/core/People.csv')

# %% [markdown]
# Compute for each player, the number of Outs pitched and batters hit. Then create a column to hold the frequency with which batters are hit.

# %%
pitches_by_playerid = pitching.groupby('playerID').agg({'HBP':sum, 'IPouts':sum})
pitches_by_playerid.loc[:, 'batter_hit_freq'] = pitches_by_playerid.HBP/pitches_by_playerid.IPouts

# %% [markdown]
# The top 20 most dangerous pitchers can be identified by sorting based on frequency

# %%
def top_n(df:pd.DataFrame, column:str, n:int=20):
    """Return the top n rows of the dataframe df when sorted by column.
    
    df: dataframe whose data needs to be sorted.
    column: column on which the rows are to be ranked
    n: number of rows to be extracted
    
    >>> df = pd.DataFrame([['a',1], ['b', 2],['c', 3],['d', 4]], columns=['alpha', 'num'])
    >>> out = top_n(df, 'num', 2)
    >>> list(out.alpha.values)
    ['d', 'c']
    >>> list(out.num.values)
    [4, 3]
    """
    return df.sort_values(by=column, ascending=False).head(n)
doctest.testmod()
# Out:
# TestResults(failed=0, attempted=4)

# %% [markdown]
# We ignore players with '0' IPouts to get rid of misleading batting hit frequency

# %%
top_20_pitchers = top_n(pitches_by_playerid.loc[pitches_by_playerid.IPouts>0], 'batter_hit_freq', 20)

# %%
top_20_pitchers
# Out:
#            HBP  IPouts  batter_hit_freq
# playerID
# sborzja01  2.0       2         1.000000
# cathete01  1.0       1         1.000000
# bleicje01  1.0       1         1.000000
# brownpe01  1.0       1         1.000000
# wilshte01  1.0       1         1.000000
# youngjb01  3.0       6         0.500000
# osikke01   3.0       6         0.500000
# moorety01  1.0       2         0.500000
# jonesga02  1.0       2         0.500000
# craigge01  2.0       5         0.400000
# burnsfa01  1.0       3         0.333333
# beckge01   1.0       3         0.333333
# jewelja01  2.0       6         0.333333
# finlest01  1.0       3         0.333333
# roberda04  2.0       6         0.333333
# gonzaga01  1.0       3         0.333333
# wallere01  1.0       3         0.333333
# gennesc01  1.0       3         0.333333
# frankja01  2.0       6         0.333333
# mejiasa01  1.0       3         0.333333

# %% [markdown]
# join top_20_pitchers dataframe with people dataframe to identify the most dangerous pitchers

# %%
top_20_pitchers.merge(people, on='playerID')[['nameFirst', 'nameLast', 'HBP', 'IPouts', 'batter_hit_freq']]
# Out:
#    nameFirst   nameLast  HBP  IPouts  batter_hit_freq
# 0        Jay      Sborz  2.0       2         1.000000
# 1        Ted     Cather  1.0       1         1.000000
# 2     Jeremy     Bleich  1.0       1         1.000000
# 3       Pete   Browning  1.0       1         1.000000
# 4      Terry  Wilshusen  1.0       1         1.000000
# 5      J. B.      Young  3.0       6         0.500000
# 6      Keith       Osik  3.0       6         0.500000
# 7      Tyler      Moore  1.0       2         0.500000
# 8    Garrett      Jones  1.0       2         0.500000
# 9     George      Craig  2.0       5         0.400000
# 10    Farmer      Burns  1.0       3         0.333333
# 11    George       Beck  1.0       3         0.333333
# 12      Jake     Jewell  2.0       6         0.333333
# 13     Steve     Finley  1.0       3         0.333333
# 14      Dale    Roberts  2.0       6         0.333333
# 15      Gabe   Gonzalez  1.0       3         0.333333
# 16       Red     Waller  1.0       3         0.333333
# 17   Scooter    Gennett  1.0       3         0.333333
# 18      Jack   Franklin  2.0       6         0.333333
# 19       Sam     Mejias  1.0       3         0.333333

# %%
# Part 2 cross-database integration analysis

# %% [markdown]
# ## Question 1

# %%
import pandas as pd
import numpy as np

# %%
people = pd.read_csv('baseballdatabank-2019.2/baseballdatabank-2019.2/core/People.csv')

# %%
people_names = people[['playerID', 'birthYear', 'nameGiven']].copy()

# %%
people_names.nameGiven.str.split(' ', expand=True).loc[:,0]
# Out:
# 0           David
# 1           Henry
# 2          Tommie
# 3          Donald
# 4          Fausto
# 5        Fernando
# 6            John
# 7          Edward
# 8            Bert
# 9         Charles
# 10        Leander
# 11          Harry
# 12        William
# 13        Jeffrey
# 14          James
# 15           Kurt
# 16       Lawrence
# 17            Ody
# 18           Paul
# 19         Albert
# 20        Francis
# 21       Reginald
# 22        William
# 23        Michael
# 24       Talmadge
# 25       Theodore
# 26         Virgil
# 27       Clifford
# 28          Harry
# 29          Shawn
#            ...
# 19587      Jordan
# 19588         Roy
# 19589        Ryan
# 19590     Charles
# 19591      Walter
# 19592       Frank
# 19593         Guy
# 19594       James
# 19595     William
# 19596        Alan
# 19597      Marion
# 19598     Richard
# 19599       Barry
# 19600     William
# 19601      Edward
# 19602    Benjamin
# 19603       Peter
# 19604      Samuel
# 19605      Edward
# 19606     William
# 19607         Jon
# 19608       Julio
# 19609        Joel
# 19610     Michael
# 19611      Robert
# 19612       Frank
# 19613        Paul
# 19614      George
# 19615      Edward
# 19616     Anthony
# Name: 0, Length: 19617, dtype: object

# %%
people_names.loc[:,'first_names']=people_names.nameGiven.str.split(' ', expand=True).loc[:,0]

# %%
people_names.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19617 entries, 0 to 19616
# Data columns (total 4 columns):
# playerID       19617 non-null object
# birthYear      19497 non-null float64
# nameGiven      19580 non-null object
# first_names    19580 non-null object
# dtypes: float64(1), object(3)
# memory usage: 613.1+ KB

# %%
people_names.dropna(how = 'any', subset = ['birthYear', 'nameGiven'], inplace=True)

# %%
people_names.birthYear = people_names.birthYear.astype(int)

# %%
people_names.birthYear.min(), people_names.birthYear.max()
# Out:
# (1820, 1998)

# %%
def process_name_file(year, gender='M'):
    file = 'names/yob{}.txt'.format(year)
    df = pd.read_csv(file, header=None, names=['Name', 'Sex', 'noccur'])
    df = df.loc[df.Sex == gender, ['Name', 'noccur']].copy()
    df.loc[:,str(year)]=df.noccur/df.noccur.sum()
    return df.drop(['noccur'], axis=1)

# %%
def process_ssn(min_year, max_year, path='names'):
    names_accum = process_name_file(min_year)
    for year in range(min_year+1, max_year+1):        
        df = process_name_file(year, gender='M')
        names_accum = names_accum.merge(df, on='Name', how='outer')
    return names_accum

# %%
names_count = (people_names.groupby(['first_names', 'birthYear'])
               .first_names
               .count()
               .rename('name_count')
              )

# %%
names_count = names_count.reset_index()

# %%
players_born = names_count.groupby('birthYear').name_count.sum().to_frame().rename(columns={'name_count':'nbirths'}).reset_index()

# %%
players_born.head()
# Out:
#    birthYear  nbirths
# 0       1820        1
# 1       1824        1
# 2       1832        3
# 3       1835        1
# 4       1836        1

# %%
names_count = names_count.merge(players_born, on='birthYear')

# %%
names_count.head()
# Out:
#   first_names  birthYear  name_count  nbirths
# 0          A.       1869           1      105
# 1   Alexander       1869           3      105
# 2      Alfred       1869           2      105
# 3    Algernon       1869           1      105
# 4     Anthony       1869           1      105

# %%
names_count.loc[:,'frequency']= names_count.name_count/names_count.nbirths

# %%
freq = process_ssn(1880, 1998)

# %%
frequency = freq.melt(id_vars = ['Name'], var_name='birthYear')

# %%
frequency.birthYear=frequency.birthYear.astype(int)

# %%
merged = names_count.merge(frequency, left_on=['birthYear','first_names'], right_on=['birthYear', 'Name'])

# %%
merged.loc[merged['frequency']>merged['value']]
# Out:
#       first_names  birthYear  name_count  nbirths  frequency         Name  \
# 0           Aaron       1896           1      135   0.007407        Aaron
# 1            Alan       1896           1      135   0.007407         Alan
# 3       Alexander       1896           1      135   0.007407    Alexander
# 4          Alfred       1896           1      135   0.007407       Alfred
# 5           Allen       1896           1      135   0.007407        Allen
# 6          Andrew       1896           1      135   0.007407       Andrew
# 9     Bartholomew       1896           1      135   0.007407  Bartholomew
# 10        Bennett       1896           1      135   0.007407      Bennett
# 11        Bernard       1896           2      135   0.014815      Bernard
# 12          Byron       1896           1      135   0.007407        Byron
# 13           Carl       1896           1      135   0.007407         Carl
# 14          Cecil       1896           1      135   0.007407        Cecil
# 15         Cedric       1896           1      135   0.007407       Cedric
# 16        Charles       1896           5      135   0.037037      Charles
# 17       Clarence       1896           2      135   0.014815     Clarence
# 18         Claude       1896           1      135   0.007407       Claude
# 19       Clifford       1896           1      135   0.007407     Clifford
# 20          Clyde       1896           1      135   0.007407        Clyde
# 21         Daniel       1896           1      135   0.007407       Daniel
# 22        Douglas       1896           1      135   0.007407      Douglas
# 25         Elwood       1896           1      135   0.007407       Elwood
# 26         Ernest       1896           1      135   0.007407       Ernest
# 27         Eugene       1896           1      135   0.007407       Eugene
# 29          Ewell       1896           1      135   0.007407        Ewell
# 30      Ferdinand       1896           1      135   0.007407    Ferdinand
# 31        Francis       1896           4      135   0.029630      Francis
# 34         George       1896           5      135   0.037037       George
# 35        Harland       1896           1      135   0.007407      Harland
# 36          Harry       1896           4      135   0.029630        Harry
# 38        Herbert       1896           2      135   0.014815      Herbert
# ...           ...        ...         ...      ...        ...          ...
# 9611      Leonard       1940           2      101   0.019802      Leonard
# 9612       Leslie       1940           1      101   0.009901       Leslie
# 9613         Lois       1940           1      101   0.009901         Lois
# 9614         Luis       1940           1      101   0.009901         Luis
# 9615      Michael       1940           2      101   0.019802      Michael
# 9616       Morris       1940           1      101   0.009901       Morris
# 9617    Nathaniel       1940           1      101   0.009901    Nathaniel
# 9618      Osvaldo       1940           1      101   0.009901      Osvaldo
# 9619      Patrick       1940           1      101   0.009901      Patrick
# 9621        Peter       1940           2      101   0.019802        Peter
# 9622        Ramon       1940           1      101   0.009901        Ramon
# 9623      Raymond       1940           1      101   0.009901      Raymond
# 9624      Richard       1940           6      101   0.059406      Richard
# 9626       Rodney       1940           1      101   0.009901       Rodney
# 9627        Roger       1940           1      101   0.009901        Roger
# 9628       Ronald       1940           3      101   0.029703       Ronald
# 9629   Rutherford       1940           1      101   0.009901   Rutherford
# 9630       Thomas       1940           4      101   0.039604       Thomas
# 9631        Tommy       1940           2      101   0.019802        Tommy
# 9632         Tony       1940           1      101   0.009901         Tony
# 9633      William       1940           5      101   0.049505      William
# 9635      Woodrow       1940           1      101   0.009901      Woodrow
# 9636        Bryse       1997           1       10   0.100000        Bryse
# 9637        Kolby       1997           1       10   0.100000        Kolby
# 9638         Kyle       1997           1       10   0.100000         Kyle
# 9639         Luis       1997           1       10   0.100000         Luis
# 9640      Michael       1997           1       10   0.100000      Michael
# 9641       Ronald       1997           1       10   0.100000       Ronald
# 9642       Victor       1997           1       10   0.100000       Victor
# 9643         Juan       1998           1        1   1.000000         Juan
#
#          value
# 0     0.000577
# 1     0.000109
# 3     0.001940
# 4     0.004408
# 5     0.001832
# 6     0.004734
# 9     0.000067
# 10    0.000151
# 11    0.002016
# 12    0.000493
# 13    0.007126
# 14    0.001673
# 15    0.000059
# 16    0.030435
# 17    0.010488
# 18    0.003329
# 19    0.002601
# 20    0.003111
# 21    0.004692
# 22    0.000602
# 25    0.000293
# 26    0.006390
# 27    0.004240
# 29    0.000042
# 30    0.000335
# 31    0.004608
# 34    0.035846
# 35    0.000042
# 36    0.017488
# 38    0.005311
# ...        ...
# 9611  0.003292
# 9612  0.001182
# 9613  0.000032
# 9614  0.000209
# 9615  0.011414
# 9616  0.000787
# 9617  0.000720
# 9618  0.000004
# 9619  0.002487
# 9621  0.004356
# 9622  0.000379
# 9623  0.008255
# 9624  0.032283
# 9626  0.001206
# 9627  0.006556
# 9628  0.017885
# 9629  0.000008
# 9630  0.020697
# 9631  0.002438
# 9632  0.001063
# 9633  0.038629
# 9635  0.000383
# 9636  0.000004
# 9637  0.000145
# 9638  0.008445
# 9639  0.003782
# 9640  0.019924
# 9641  0.001112
# 9642  0.001964
# 9643  0.003852
#
# [7963 rows x 7 columns]
